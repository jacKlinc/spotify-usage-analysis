# %%
import pandas as pd

# %%
stream_hist = pd.read_json('/home/buscemi/spotify_stats/data/json_files_29May2020/StreamingHistory0.json')

stream_hist.head(20)
# Out:
#              endTime                 artistName  \
# 0   2019-05-28 11:02    Boogie Down Productions
# 1   2019-05-28 11:02           Afrika Bambaataa
# 2   2019-05-28 11:06                    Skee-Lo
# 3   2019-05-28 11:10                 Slick Rick
# 4   2019-05-28 11:10                  Dead Prez
# 5   2019-05-28 11:10                 Atmosphere
# 6   2019-05-28 11:10                 Jurassic 5
# 7   2019-05-28 11:10                 Atmosphere
# 8   2019-05-28 11:10           Jedi Mind Tricks
# 9   2019-05-28 11:10            Eric B. & Rakim
# 10  2019-05-28 11:10                   Young MC
# 11  2019-05-28 11:15                The Animals
# 12  2019-05-28 11:16             Wilson Pickett
# 13  2019-05-28 11:16        Yusuf / Cat Stevens
# 14  2019-05-28 11:16                   Lou Reed
# 15  2019-05-28 11:16                Johnny Cash
# 16  2019-05-28 11:16  Nick Cave & The Bad Seeds
# 17  2019-05-28 11:17            The Temptations
# ...

# %%
# Artists
stream_hist.artistName.unique()
# Out:
# array(['Boogie Down Productions', 'Afrika Bambaataa', 'Skee-Lo', ...,
#        'David Lee Roth', 'Rush', 'New York Dolls'], dtype=object)

# %% [markdown]
# ### Finding the mean listen time

# %%
mean_played = stream_hist.msPlayed.mean()
mean_played
# Out:
# 44173.3851

# %%
# How far each song listen time is from the average
stream_hist.msPlayed.map(lambda x: x - mean_played)
# Out:
# 0       -38935.3851
# 1       -35514.3851
# 2       208132.6149
# 3       -44173.3851
# 4       -43352.3851
#            ...
# 9995    -39179.3851
# 9996    -44173.3851
# 9997    -43183.3851
# 9998    -41430.3851
# 9999    -44173.3851
# Name: msPlayed, Length: 10000, dtype: float64

# %%
stream_hist.head()
# Out:
#             endTime               artistName            trackName  msPlayed
# 0  2019-05-28 11:02  Boogie Down Productions   The Bridge Is Over      5238
# 1  2019-05-28 11:02         Afrika Bambaataa          Planet Rock      8659
# 2  2019-05-28 11:06                  Skee-Lo  I Wish - Radio Edit    252306
# 3  2019-05-28 11:10               Slick Rick       Street Talkin'         0
# 4  2019-05-28 11:10                Dead Prez              Hip Hop       821
